# %% [markdown]
# ## Introduction to Stats in Python Studio
#
# We are going to be working with this [dataset](https://www.kaggle.com/andrewmvd/heart-failure-clinical-data) from Kaggle.  No need to download, as it is included in the git repository you just cloned.
# <br>
#
# Heart Disease is the number 1 cause of death globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide.
# <br>
#
# Heart failure is a common event caused by heart disease and this dataset contains 12 features that can be used to predict mortality by heart failure. You are tasked to look at two particular variables and record your observations about their usefulness for predicting the probability of heart failure.
# <br>
#
# In section one, you will be asked to run some simple EDA and apply statistical terminology to describe each variable in more detail.  Section two will explore what the distribution of your variables looks like. Finally, in section three you will be asked to make some inferences about your variables and if you feel they are good indicators of predicting heart failure.
# <br>
#
# Answer the questions and record your observations in the space provided. Feel free to add more code blocks if you'd like.
# <br>

# %% [raw]
# Description of Data:
#
# Sex - Gender of patient Male = 1, Female =0
# Age - Age of patient
# Diabetes - 0 = No, 1 = Yes
# Anaemia - 0 = No, 1 = Yes
# High_blood_pressure - 0 = No, 1 = Yes
# Smoking - 0 = No, 1 = Yes
# DEATH_EVENT - 0 = No, 1 = Yes

# %%
# Import libries need with alias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')


# Set style and font size
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# %%
# Read in data to a dataframe
url = 'https://raw.githubusercontent.com/e3la/IntroToStatsStudio/main/heart3.csv'
df= pd.read_csv(url)

# %% [markdown]
# ## Section 1: First look at the data:
#
# Run some simple EDA and look at the data and your variables. Answer the following questions.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
print(df['anaemia'].sum())
print(df['diabetes'].sum())
print(df.describe(include=[np.number]))
# Out:
# 129
# 125
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %% [markdown]
# Which of our columns are catogorical data?
# <BR><BR>
# * anaemia, diabetes, high blood pressure, sex, smoking, death event<BR><BR><p>
# Which of our columns are continuous?
# <BR><BR>
# * age, creatinine_phosphokinase, ejection_fraction, platelets, serum_creatinine, serum_sodium, time<BR><BR>

# %% [markdown]
# ### Statistical interpretation of our data?
# #### First Variable:
# Mean, Min, Max, STD? Describe what this means.
# <br><br>
# Age:<br>
#
# |   Statistic   |      Value       |
# |:-------------:|:----------------:|
# |     Mean      |   60.833893      |
# |     Min       |   40.000000      |
# |     Max       |   95.000000      |
# |     Std       |   11.894809      |
#
# The mean age is all the ages divided by the number of ages in the dataset.
#
# The minimum age is 40, no one younger than forty is in the dataset for having heart failure.
#
# The oldest age is 95.
#
# The standard deviation is 11.89
#
# The average is 60, on an average the data values cluster up around 60 and the standard deviation of 11.89 or 12ish depicts that the value by which our mean may deviate maybe +12ish or -12ish. This means that our mean may vary from 48 to 72 in the real population.
#
#
# #### Second Variable:
# Mean, Min, Max, STD? Describe what this means.
#
# platelets
#
# |   Statistic   |      Value       |
# |:-------------:|:----------------:|
# |     Mean      | 263358.029264    |
# |     Min       | 25100.000000     |
# |     Max       | 850000.000000    |
# |     Std       | 97804.236869     |
#
#
# The mean platelets in the blood is 263358 (kiloplatelets/mL) is all the platelet values divided by the number of platelet values in the dataset.
#
# The minimum platelet is 25100, no one has less than that many.
#
# The most platelet recorded is 850000.
#
# The standard deviation is 97804
#
# The average is 263358, on an average the data values cluster up around 263358 and the standard deviation of 97804 depicts that the value by which our mean may deviate maybe +97804 or -97804. This means that our mean may vary from 165554 to 361162 in the real population.
#
#
# <br><br><br>
#
# What could the numbers in our categorical data tell us?
#
# How many people in the dataset have diabetes, or smoked in the dataset or how many died during the follow-up period in the dataset.
#
#
#
# <br><br><br>
#
# Why might we want to keep our categorical data as 1's and 0's? Why may we want to use something like the code below to change it?
#
# I think Yes and No as 1 and 0 is pretty easy, and it can give you an easy way to count - sum - all the yeses. Male and female should be changed, as should alive or dead, because denoting either of those with a simple boolean make the data less clear. Or be an unfair data practice because denegrating women to zero is a bit rude.

# %%
print(df['age'].describe())
# Out:
# count    299.000000
# mean      60.833893
# std       11.894809
# min       40.000000
# 25%       51.000000
# 50%       60.000000
# 75%       70.000000
# max       95.000000
# Name: age, dtype: float64

# %%
print(df['platelets'].describe())
# Out:
# count       299.000000
# mean     263358.029264
# std       97804.236869
# min       25100.000000
# 25%      212500.000000
# 50%      262000.000000
# 75%      303500.000000
# max      850000.000000
# Name: platelets, dtype: float64

# %%
#df['sex'] = df.sex.replace({1: "Male", 0: "Female"})
#df['anaemia'] = df.anaemia.replace({1: "Yes", 0: "No"})
#df['diabetes'] = df.diabetes.replace({1: "Yes", 0: "No"})
#df['high_blood_pressure'] = df.high_blood_pressure.replace({1: "Yes", 0: "No"})
#df['smoking'] = df.smoking.replace({1: "Yes", 0: "No"})

#df['DEATH_EVENT'] = df.DEATH_EVENT.replace({1: "Died", 0: "Alive"})

# %% [markdown]
# ## Section 2: Distribution of our data:

# %%
# Plot the distribution of your AGE variable using distplot

sns.distplot(df['age'])
plt.show()

# %%
# Plot the distribution of your AGE variable using distplot

sns.distplot(df['sex'])
plt.show()

# %%
# Create boxplot to show distribution of variable

fig, ax = plt.subplots()
ax.boxplot(df['age'])
plt.show()

# %%
# Create boxplot to show distribution of variable

fig, ax = plt.subplots()
ax.boxplot(df['sex'])
plt.show()

# %%
# Feel free to add any additional graphs that help you answer the questions below.
plt.hist(df['age'])
plt.show()

# %%
# Feel free to add any additional graphs that help you answer the questions below.
plt.hist(df['sex'])
plt.show()

# %%
# Another way to check the skewness of our variable
df['age'].skew()
# Out:
# 0.42306190672863536

# %%
# Another way to check the kurtosis of our variable
df['age'].kurtosis()
# Out:
# -0.18487053195417413

# %% [markdown]
# ### Interpretation of how our data is distributed by variable?
# Looking at the above graphs, what can you tell about the distribution of your variables?
# <br><br><br><br><br>
# What is the skewness and kurtosis of your variables.  What does this mean?<br>
# <br><br><br><br><br>
# What are some of the differences you note looking at a categorical variable vs a continuous variable?
# <br><br><br><br><br>

# %% [markdown]
# ## Section 3: Finding Correlations
#
# Lets start by breaking our data into two.

# %%
# splitting the dataframe into 2 parts
# on basis of ‘DEATH_EVENT’ column values
df_died = df[df['DEATH_EVENT'] == 1 ]
df_lived = df[df['DEATH_EVENT'] == 0 ]

# %%
# Plot your variable based on if they died or lived

sns.distplot(df_died['sex'])
sns.distplot(df_lived['sex'])
plt.title("Chances of survival vs sex")
plt.legend(('Died','Lived'))
plt.plot()
# Out:
# []

# %%
# Feel free to add any additional graphs that help you answer the questions below.

# %% [markdown]
# #### What things can you infer if we consider our data a sample of the population, based on each of your variables.
# <br><br><br><br><br>
# #### Do you think either of your variables is a good indicator for predicting Heart Failure, why or why not?
# <br><br><br><br><br>
